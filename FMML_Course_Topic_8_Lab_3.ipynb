# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaRocky02/Fmml_Projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 09:43:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   131MB/s    in 0.5s
#
# 2024-03-26 09:44:00 (131 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11082   1404.4175v1  Brain decoding is a data analysis paradigm for...  stat
# 21761   1207.3649v1  We consider probabilistic multinomial probit c...  stat
# 36270   1202.0984v1  Seven years on from OWL becoming a W3C recomme...    cs
# 27779  1704.04952v2  Dominant approaches to action detection can on...    cs
# 7127   1710.07138v2  Reducing labeling costs in supervised learning...  stat
# ...             ...                                                ...   ...
# 22765  1706.01865v1  Performance of machine learning approaches dep...  stat
# 10512   1205.2641v1  Methods for automated discovery of causal rela...  stat
# 6791   1706.02409v1  We introduce a flexible family of fairness reg...    cs
# 33101  1802.04822v1  The surging availability of electronic medical...    cs
# 22191  1507.03176v1  Nonnegative Matrix Factorization (NMF) aims to...  stat
#
#                                                    title  year  \
# 11082                       MEG Decoding Across Subjects  2014
# 21761  Nested Expectation Propagation for Gaussian Pr...  2012
# 36270             OWL: Yet to arrive on the Web of Data?  2012
# 27779  AMTnet: Action-Micro-Tube Regression by End-to...  2017
# 7127   Binary Classification from Positive-Confidence...  2017
# ...                                                  ...   ...
# 22765                         Shape Parameter Estimation  2017
# 10512  Bayesian Discovery of Linear Acyclic Causal Mo...  2012
# 6791              A Convex Framework for Fair Regression  2017
# 33101  Identify Susceptible Locations in Medical Reco...  2018
# 22191  Dependent Indian Buffet Process-based Sparse N...  2015
#
#                                                 keywords
# 11082  [neuroimaging, experiments, predicting, presen...
# 21761  [probabilistic, multinomial, classification, c...
# 36270  [recommendation, recommendation, experienced, ...
# 27779  [approaches, detection, solutions, detections,...
# 7127   [supervised, practical, applications, confiden...
# ...                                                  ...
# 22765  [performance, approaches, parameters, threshol...
# 10512  [automated, discovery, relationships, interven...
# 6791   [introduce, regularizers, regression, regulari...
# 33101  [availability, electronic, increased, interest...
# 22191  [nonnegative, factorization, factorize, optimi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11082    [neuroimaging, experiments, predicting, presen...
# 21761    [probabilistic, multinomial, classification, c...
# 36270    [recommendation, recommendation, experienced, ...
# 27779    [approaches, detection, solutions, detections,...
# 7127     [supervised, practical, applications, confiden...
#                                ...
# 36866    [prediction, applications, comprehensive, attr...
# 34254    [witnessed, answering, information, introduce,...
# 6069     [prediction, anopheles, environmental, variabl...
# 6415     [correction, establish, existence, clustering,...
# 980      [likelihood, rewritten, parametrized, probabil...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8841 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02019dc6-478b-48e6-a929-038c49d8bea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02019dc6-478b-48e6-a929-038c49d8bea8")) {                    Plotly.newPlot(                        "02019dc6-478b-48e6-a929-038c49d8bea8",                        [{"x":["difficulty","specifically","combining","producing","presented","functional","contributions","consistently","neuroimaging","structural","transductive","sometimes","following","classifier","classifiers","modelling","straightforward","technique","predicting","inference","variability","experiments","magnetoencephalographic","unsuccessful","concurrent","generalization","differences","numerical","consistent","assumptions","different","quadratures","benchmark","computations","distribution","challenges","propagation","concerned","approximations","likelihood","approximates","accurately","classification","approximate","expectation","multinomial","integration","predictive","approaches","posterior","probabilistic","facilitate","variables","variational","independence","dependencies","multiclass","community","simplified","suggested","tractable","neglected","implementations","conclusion","recommendation","experienced","publishers","particular","encompassing","processing","effectively","promising","implementation","appearance","outperform","regression","localisation","proposals","algorithm","exploiting","trainable","detection","detections","successive","evolution","classical","optimised","framework","computation","providing","radically","solutions","architecture","expensive","estimation","clustering","implemented","extension","consistency","unlabeled","formulation","efficiently","parameter","estimating","applications","minimization","confidence","demonstrate","empirical","discriminative","theoretically","practical","computationally","describing","classifying","difference","usefulness","bottleneck","supervised","parameters","establish","convolutional","including","independent","verification","experimental","distributional","therefore","confirmed","demonstrated","sufficiently","uncertainty","deterministic","extracted","structure","forecasts","applicability","forecasting","decisions","demanding","political","outperforms","intersection","television","substantiate","performance","especially","algorithms","currently","adversarial","dimension","formalized","constructive","optimization","convexity","partially","functions","dimensional","challenging","attribute","meaningful","therapeutic","techniques","reduction","minimizing","performed","microarray","absolutely","procedure","comprehensive","effective","statistical","prediction","attributes","participate","expression","development","irrelevant","combination","specificity","sensitivity","evaluation","precision","filtering","heterogeneity","significant","threatening","international","diagnosis","inception","obtaining","evaluated","representation","developed","collaboration","pretrained","classifies","organized","dermoscopic","malignant"],"y":[48,168,114,30,171,41,56,33,6,66,5,26,93,145,132,48,20,266,77,195,28,579,0,2,6,110,57,95,90,72,741,0,205,40,232,123,79,16,35,69,12,60,514,103,32,6,33,56,429,40,159,33,133,41,36,57,10,67,11,29,27,3,46,18,37,8,4,265,4,275,115,108,115,78,100,132,7,17,860,66,22,333,16,9,64,99,2,494,133,83,2,158,226,43,194,140,100,71,71,47,69,148,119,60,364,62,32,514,161,86,43,126,73,43,37,66,33,9,185,242,50,374,240,151,40,392,17,159,13,99,21,90,34,102,338,5,43,22,66,11,10,275,23,2,1,880,111,597,41,121,57,10,10,307,13,48,230,170,223,39,44,1,380,90,39,122,4,5,118,58,237,169,237,58,3,49,114,18,144,9,38,259,78,71,4,235,2,16,52,15,34,164,338,191,11,13,7,18,2,4],"type":"bar"},{"x":["difficulty","specifically","combining","producing" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.41747572815533984);'>Estimating</span> <span style=''>snow</span> <span style=''>cover</span> <span style=''>from</span> <span style=''>publicly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>images</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.41747572815533984);'>estimating</span> <span style=''>snow</span> <span style=''>cover</span> <span style=''>in</span> <span style=''>mountainous</span> <span style=''>regions</span> <span style=''>that</span> <span style=''>is</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>extent</span> <span style=''>of</span> <span style=''>the</span> <span style=''>earth</span> <span style=''>surface</span> <span style=''>covered</span> <span style=''>by</span> <span style=''>snow</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>publicly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>visual</span> <span style=''>content</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>photographs</span> <span style=''>and</span> <span style=''>image</span> <span style=''>feeds</span> <span style=''>from</span> <span style=''>outdoor</span> <span style=''>webcams</span> <span style=''>can</span> <span style=''>both</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>leveraged</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style=''>sources</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>complementing</span> <span style=''>existing</span> <span style=''>ground</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satellite</span> <span style=''>and</span> <span style=''>airborne</span> <span style=''>sensor</span> <span style=''>data</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>two</span> <span style=''>content</span> <span style='background-color:rgba(0, 255, 0, 0.3220338983050846);'>acquisition</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.41388174807197936);'>processing</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333333);'>pipelines</span> <span style=''>that</span> <span style=''>are</span> <span style=''>tailored</span> <span style=''>to</span> <span style=''>such</span> <span style=''>sources</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>addressing</span> <span style=''>the</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3155080213903743);'>challenges</span> <span style=''>posed</span> <span style=''>by</span> <span style=''>each</span> <span style=''>of</span> <span style=''>them</span> <span style=''>eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style=''>mountain</span> <span style=''>peaks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>out</span> <span style=''>images</span> <span style=''>taken</span> <span style=''>in</span> <span style=''>bad</span> <span style=''>weather</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>handling</span> <span style=''>varying< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MML</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>Neyman</span> <span style=''>Scott</span> <br/><br/><span style=''>Strict</span> <span style=''>Minimum</span> <span style=''>Message</span> <span style=''>Length</span> <span style=''>(SMML)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>method</span> <span style=''>widely</span> <span style=''>cited</span> <span style=''>(but</span> <span style=''>only</span> <span style=''>with</span> <span style=''>informal</span> <span style=''>arguments)</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimations</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>problems</span> <span style=''>It</span> <span style=''>is</span> <span style=''>however</span> <span style=''>almost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>for</span> <span style=''>which</span> <span style=''>reason</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>it</span> <span style=''>(known</span> <span style=''>as</span> <span style=''>MML</span> <span style=''>algorithms)</span> <span style=''>are</span> <span style=''>ever</span> <span style=''>used</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>Neyman</span> <span style=''>Scott</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>problem</span> <span style=''>an</span> <span style=''>oft</span> <span style=''>cited</span> <span style=''>showcase</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>MML</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>even</span> <span style=''>with</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>prior</span> <span style=''>neither</span> <span style=''>SMML</span> <span style=''>nor</span> <span style=''>its</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>it</span> <span style=''>thereby</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterexample</span> <span style=''>to</span> <span style=''>the</span> <span style=''>general</span> <span style=''>claim</span> <span style=''>This</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>known</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>an</span> <span style=''>SMML</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>hi ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4473684210526316);'>parametric</span> <span style=''>Markov</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3106704438149197);'>information</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>Markov</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>data</span> <span style=''>without</span> <span style=''>invoking</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3856812933025405);'>variables</span> <span style=''>The</span> <span style=''>method</span> <span style=''>makes</span> <span style=''>use</span> <span style=''>of</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>on</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4473684210526316);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.7572254335260117);'>estimator</span> <span style=''>for</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3106704438149197);'>information</span> <span style=''>which</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>create</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4473684210526316);'>parametric</span> <span style=''>test</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.4956521739130436);'>multivariate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>test</span> <span style=''>is</span> <span style=''>then</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.47747747747747743);'>evaluated</span> <span style=''>on</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3255131964809384);'>synthetic</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerably</span> <span style=''>more</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>than</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competing</span> <span style=''>methods</span> <span style=''>w ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>Sieve</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intuitively</span> <span style=''>data</span> <span style=''>is</span> <span style=''>passed</span> <span style=''>through</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>progressively</span> <span style=''>fine</span> <span style=''>grained</span> <span style=''>sieves</span> <span style=''>Each</span> <span style=''>layer</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sieve</span> <span style=''>recovers</span> <span style=''>a</span> <span style=''>single</span> <span style=''>latent</span> <span style=''>factor</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>The</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformed</span> <span style=''>after</span> <span style=''>each</span> <span style=''>pass</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remaining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unexplained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>trickles</span> <span style=''>down</span> <span style=''>to</span> <span style=''>the</span> <span style=''>next</span> <span style=''>layer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Ultimately</span> <span style=''>we</span> <span style=''>are</span> <span style=''>left</span> <span style=''>with</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>factors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explaining</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>original</span> <span style=''>data</span> <span style=''>and</span> <span style=''>remainder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>noise</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>this</span> <span style='background-c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08109077861499821)
# 	evaluation (0.09293146752780768)
# 	knowledge (0.12737710800143523)
# 	segmentation (0.07140294223179046)
# 	experimental (0.14065303193397918)
# 	detection (0.11948331539289558)
# 	information (0.24901327592393255)
# 	different (0.2658772874058127)
# 	convolutional (0.134194474345174)
# 	recognition (0.13311804808037317)
#
# Some Statistics words are:
# 	statistical (0.14754098360655737)
# 	stochastic (0.13263785394932937)
# 	variational (0.10680576254346746)
# 	theoretical (0.15250869349230006)
# 	distribution (0.18281172379533037)
# 	variables (0.14903129657228018)
# 	estimation (0.17834078489816194)
# 	dimensional (0.19026328862394437)
# 	regression (0.17734724292101342)
# 	inference (0.20914058618976653)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="848b97cb-dc8c-4c6f-aa00-dc7b0668df2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("848b97cb-dc8c-4c6f-aa00-dc7b0668df2f")) {                    Plotly.newPlot(                        "848b97cb-dc8c-4c6f-aa00-dc7b0668df2f",                        [{"x":["difficulty","specifically","combining","producing","presented","functional","contributions","consistently","neuroimaging","structural","transductive","sometimes","following","classifier","classifiers","modelling","straightforward","technique","predicting","inference","variability","experiments","magnetoencephalographic","unsuccessful","concurrent","generalization","differences","numerical","consistent","assumptions","different","quadratures","benchmark","computations","distribution","challenges","propagation","concerned","approximations","likelihood","approximates","accurately","classification","approximate","expectation","multinomial","integration","predictive","approaches","posterior","probabilistic","facilitate","variables","variational","independence","dependencies","multiclass","community","simplified","suggested","tractable","neglected","implementations","conclusion","recommendation","experienced","publishers","particular","encompassing","processing","effectively","promising","implementation","appearance","outperform","regression","localisation","proposals","algorithm","exploiting","trainable","detection","detections","successive","evolution","classical","optimised","framework","computation","providing","radically","solutions","architecture","expensive","estimation","clustering","implemented","extension","consistency","unlabeled","formulation","efficiently","parameter","estimating","applications","minimization","confidence","demonstrate","empirical","discriminative","theoretically","practical","computationally","describing","classifying","difference","usefulness","bottleneck","supervised","parameters","establish","convolutional","including","independent","verification","experimental","distributional","therefore","confirmed","demonstrated","sufficiently","uncertainty","deterministic","extracted","structure","forecasts","applicability","forecasting","decisions","demanding","political","outperforms","intersection","television","substantiate","performance","especially","algorithms","currently","adversarial","dimension","formalized","constructive","optimization","convexity","partially","functions","dimensional","challenging","attribute","meaningful","therapeutic","techniques","reduction","minimizing","performed","microarray","absolutely","procedure","comprehensive","effective","statistical","prediction","attributes","participate","expression","development","irrelevant","combination","specificity","sensitivity","evaluation","precision","filtering","heterogeneity","significant","threatening","international","diagnosis","inception","obtaining","evaluated","representation","developed","collaboration","pretrained","classifies","organized","dermoscopic","malignant","challenge","validation","analyzing","automated","selection","incorrect","submodular","submodularity","stochastic","appearing","correctness","situations","discussions","detecting","embedding","relatively","competitively","annotated","discussion","improving","disagreement","embarrassingly","arbitrarily","resulting","generates","independently","empirically","asymptotically","processed","partition","parallelize","requirements","communication","synchronization","locations","inefficiency","introduce","permitting","prohibitive","converges","diagnostics","importance","optimally","ensembles","synthetic","benchmarks","convergence","integrands","quadrature","introduced","underlying","discriminate","estimator","unsupervis ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	magnetoencephalographic
# 	quadratures
# 	integrands
# 	quadrature
# 	sophistication
# 	idealized
# 	refitting
# 	repulsion
# 	additivity
# 	uncoupled
# 	collapsing
# 	autoencoding
# 	nomination
# 	epanechnikov
# 	recasting
# 	metabolic
# 	barycenter
# 	barycenters
# 	elucidating
# 	decomposability
# Some words which never appear in Statistics papers:
# 	publishers
# 	television
# 	threatening
# 	dermoscopic
# 	cooperate
# 	contenders
# 	occlusions
# 	refinenet
# 	egocentric
# 	starcraft
# 	deblurring
# 	pipelined
# 	stylistic
# 	transmitting
# 	transmitted
# 	progressive
# 	democratize
# 	interrogative
# 	philosophical
# 	permission

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081949024563134e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
